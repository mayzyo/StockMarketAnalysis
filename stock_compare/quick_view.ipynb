# %%
import pandas as pd
import numpy as np
import mplfinance as mpf
import yfinance as yf

# %%
stock = yf.Ticker("IVV.AX")

dfnm = stock.history(start="2015-01-01", end="2025-01-01")
dfnm.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  2532.000000  2532.000000  2532.000000  2532.000000  2.532000e+03
# mean     30.079930    30.156438    29.985408    30.068064  2.080589e+05
# std      12.912564    12.934340    12.891392    12.912805  1.722817e+05
# min      13.818330    13.818330    13.641002    13.689567  0.000000e+00
# 25%      18.842753    18.880120    18.805844    18.844780  1.197505e+05
# 50%      27.825048    27.889280    27.726615    27.799842  1.648200e+05
# 75%      38.494728    38.584421    38.415801    38.490500  2.345782e+05
# max     246.056503   246.056503   246.056503   246.056503  2.612429e+06
#
#          Dividends  Stock Splits  Capital Gains
# count  2532.000000        2532.0         2532.0
# mean      0.001976           0.0            0.0
# std       0.015957           0.0            0.0
# min       0.000000           0.0            0.0
# 25%       0.000000           0.0            0.0
# ...

# %%
dfnm.to_csv('./stock.csv')
