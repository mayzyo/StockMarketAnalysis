# %%
import pandas as pd
import numpy as np
import mplfinance as mpf
from pandas_datareader import data as pdr
import nbimporter
from src.notes.experiment_3 import read_data
from src.notes.experiment_2.fundamentals import
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\micha\Projects\StockMarketAnalysis\lib\site-packages\ipython_genutils\ipstruct.py in __getattr__(self, key)
#     131         try:
# --> 132             result = self[key]
#     133         except KeyError:
#
# KeyError: 'language'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_128/3643082133.py in <module>
#       5 import nbimporter
#       6 from src.notes.experiment_3 import read_data
# ----> 7 from src.notes.experiment_2 import fundamentals
#
# ~\AppData\Local\Programs\Python\Python38\lib\importlib\_bootstrap.py in _find_and_load(name, import_)
#
# ~\AppData\Local\Programs\Python\Python38\lib\importlib\_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ...

# %%
data = pd.read_csv('tables', sep='\t\t|\t')
ths_df = read_data.clean_data(data)
# Out:
# c:\Users\micha\Projects\StockMarketAnalysis\lib\site-packages\pandas\util\_decorators.py:311: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   return func(*args, **kwargs)

# %%
import yfinance as yf
tickers = yf.Tickers(' '.join(ths_df['Ticker']))

# %%
tickers.tickers['000001.SZ'].info
# Out:
# {'zip': '518001',
#  'sector': 'Financial Services',
#  'fullTimeEmployees': 36115,
# ...

# %%
import yfinance as yf
tickers = yf.Tickers('msft aapl goog')
tickers
# Out:
# yfinance.Tickers object <MSFT,AAPL,GOOG>

# %%
tickers.tickers['MSFT'].info
# Out:
# {'zip': '98052-6399',
#  'sector': 'Technology',
#  'fullTimeEmployees': 181000,
# ...
